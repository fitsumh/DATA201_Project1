# %% [markdown]
# <a href="https://colab.research.google.com/github/fitsumh/DATA201_Project1/blob/master/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# The dataset is from kaggle https://www.kaggle.com/hussainahmedalmusawi/insurance-charges
# The dataset has 1338 rows and 7 columns. The columns are as follows:
#
# age: age of primary beneficiary
#
# sex: insurance contractor gender, female, male
#
# bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,
# objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
#
# children: Number of children covered by health insurance / Number of dependents
#
# smoker: Smoking
#
# region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
#
# charges: Individual medical costs billed by health insurance

# %% [markdown]
# Using different python libraries we will prepare, explore, and analyse the data. First let's prepare and wrangle the dataset using the numpy and pandas libraries.
#
# In this section we will answer such questions as how many rows and columns does the dataset has, what is the data type of our variables, whether we have missing values, and view some summary statistic of the variables.

# %%
# reading in the finle into pandas dataframe

medCosts = pd.read_csv("insurance.csv")

# %%
medCosts
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Examine first few rows of the dataframe
medCosts.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
medCosts.dtypes  # Viewing what the type of data each columns are
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
medCosts.describe(include='all')
# Out:
#                 age   sex          bmi  ...  smoker     region       charges
# count   1338.000000  1338  1338.000000  ...    1338       1338   1338.000000
# unique          NaN     2          NaN  ...       2          4           NaN
# top             NaN  male          NaN  ...      no  southeast           NaN
# freq            NaN   676          NaN  ...    1064        364           NaN
# mean      39.207025   NaN    30.663397  ...     NaN        NaN  13270.422265
# std       14.049960   NaN     6.098187  ...     NaN        NaN  12110.011237
# min       18.000000   NaN    15.960000  ...     NaN        NaN   1121.873900
# 25%       27.000000   NaN    26.296250  ...     NaN        NaN   4740.287150
# 50%       39.000000   NaN    30.400000  ...     NaN        NaN   9382.033000
# 75%       51.000000   NaN    34.693750  ...     NaN        NaN  16639.912515
# max       64.000000   NaN    53.130000  ...     NaN        NaN  63770.428010
#
# [11 rows x 7 columns]

# %%
medCosts["region"].unique()  # How many regions are identified in the dataset
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
medCosts["region"].value_counts()   # How many entries are from each region?
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
medCosts["age"].value_counts() # Do the same thing with the age column.
# Out:
# 18    69
# 19    68
# 51    29
# 45    29
# 46    29
# 47    29
# 48    29
# 50    29
# 52    29
# 20    29
# 26    28
# 54    28
# 53    28
# 25    28
# 24    28
# 49    28
# 23    28
# 22    28
# 21    28
# 27    28
# 28    28
# 31    27
# 29    27
# 30    27
# 41    27
# 43    27
# 44    27
# 40    27
# 42    27
# 57    26
# 34    26
# 33    26
# 32    26
# 56    26
# 55    26
# 59    25
# 58    25
# 39    25
# 38    25
# 35    25
# 36    25
# 37    25
# 63    23
# 60    23
# 61    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
medCosts["age"].describe()  # get a summary of the age of our participants
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
medCosts["charges"].describe()  # get summary statistics for the charges in our dataset
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
medCosts["charges"].median()
# Out:
# 9382.033

# %%
medCosts.isnull()  # try to determine if there are NA values in our data
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
medCosts.isnull().sum() # This gives us a cleaner count of NA values in all variables
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# In the section below we will explore what kind of relationship exists between the variables if any by using the heatmap function from Matplotlib.

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Examine correlation bewtween the features using heatmap to identify the ones with strong correlation
plt.figure(figsize=(10,5))
c = medCosts.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %% [markdown]
# According to the heatmap above the variables age and charge appear to have a some kind of a correlations.

# %%
# Examining the relationship between age and charges further to prepare for nonparametric inference for the median of a continuous variable using bootstrap simulation.
grouped = medCosts.groupby('age')

# %%
grouped

# %%
grouped.sum()
# Out:
#           bmi  children        charges
# age
# 18   2161.505        31  488949.011389
# 19   1944.590        29  662857.834750
# 20    888.350        25  294631.234350
# 21    789.200        22  132453.001230
# 22    870.455        20  280362.118450
# 23    880.725        28  347754.961110
# 24    815.995        13  298144.446940
# 25    831.430        36  275474.228700
# 26    824.010        30  171747.108640
# 27    821.340        27  341171.648200
# 28    825.500        36  253937.251800
# 29    793.345        34  281614.285630
# 30    825.055        42  343415.979670
# 31    807.795        38  275318.475480
# 32    821.540        33  239727.807560
# 33    810.240        40  321139.857670
# 34    787.125        30  301951.731140
# 35    784.870        42  282679.550780
# 36    734.355        31  305111.903450
# 37    780.415        38  450497.796930
# 38    724.915        37  202568.341850
# 39    747.755        55  294456.073630
# 40    813.755        43  317850.785370
# 41    850.685        38  260651.132540
# 42    818.860        27  352648.044060
# 43    815.520        44  520216.523640
# 44    832.795        33  428203.707850
# 45    863.590        43  430075.795830
# 46    908.885        47  415935.128520
# 47    889.265        40  511965.988200
# 48    925.845        38  424342.512910
# 49    848.790        42  355488.175400
# 50    902.835        38  454227.095720
# 51    920.085        32  454785.420150
# 52    955.145        43  529431.821860
# 53    850.105        35  448586.061140
# 54    874.560        40  525239.301310
# 55    830.700        25  420278.182700
# 56    821.625        20  390663.411750
# 57    801.955        16  427626.816500
# 58    817.955         6  346973.202790
# 59    764.300        30  472396.738290
# 60    697.655         8  505526.625670
# 61    748.610        17  506562.525000
# 62    743.880        13  440768.701190
# 63    734.240        13  457354.964600
# 64    725.475        17  512061.678420

# %%
grouped.describe()
# Out:
#       bmi                       ...       charges
#     count       mean       std  ...           50%           75%          max
# age                             ...
# 18   69.0  31.326159  6.970188  ...   2198.189850  11272.331390  38792.68560
# 19   68.0  28.596912  5.859832  ...   2135.891875  17148.980075  39722.74620
# 20   29.0  30.632759  4.629494  ...   2459.720100  17085.267600  38344.56600
# 58   25.0  32.718200  6.021369  ...  11931.125250  12231.613600  47496.49445
# 59   25.0  30.572000  4.762225  ...  12928.791100  21797.000400  48970.24760
# 60   23.0  30.332826  5.753496  ...  13204.285650  29591.566240  52590.82939
# 61   23.0  32.548261  6.136227  ...  13635.637900  29005.012100  48517.56315
# 62   23.0  32.342609  5.030660  ...  13844.797200  21306.589040  46718.16325
# 63   23.0  31.923478  5.998858  ...  14349.854400  15362.628875  48824.45000
# 64   22.0  32.976136  5.762155  ...  15528.758375  28757.715888  49577.66240
#
# [47 rows x 24 columns]

# %%
# index the data to just get age and charges

medCosts2 = medCosts[['age', 'charges']]

# %%
medCosts2
# Out:
#       age      charges
# 0      19  16884.92400
# 1      18   1725.55230
# 2      28   4449.46200
# 3      33  21984.47061
# 4      32   3866.85520
# ...   ...          ...
# 1333   50  10600.54830
# 1334   18   2205.98080
# 1335   18   1629.83350
# 1336   21   2007.94500
# 1337   61  29141.36030
#
# [1338 rows x 2 columns]

# %%
medCosts2.describe()  # get summary statistics for the two features
# Out:
#                age       charges
# count  1338.000000   1338.000000
# mean     39.207025  13270.422265
# std      14.049960  12110.011237
# min      18.000000   1121.873900
# 25%      27.000000   4740.287150
# 50%      39.000000   9382.033000
# 75%      51.000000  16639.912515
# max      64.000000  63770.428010

# %% [markdown]
# The correlation between age and charges is plotted below using the matplotlib library

# %%
plt.scatter(medCosts2['age'], medCosts2['charges'], marker = 'o', alpha = 0.5)

# %%
avgCostbyAge = medCosts2.groupby('age').mean()

# %%
plt.plot(avgCostbyAge)

# %%
plt.hist(medCosts['age'])
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(medCosts['charges'])
# Out:
# (array([536., 398., 129.,  86.,  35.,  59.,  57.,  32.,   2.,   4.]),
#  array([ 1121.8739  ,  7386.729311, 13651.584722, 19916.440133,
#         26181.295544, 32446.150955, 38711.006366, 44975.861777,
#         51240.717188, 57505.572599, 63770.42801 ]),
#  <a list of 10 Patch objects>)

# %%
sns.set_style("darkgrid")

# %%
sns.boxplot(x = medCosts['charges'])

# %%
sns.boxplot(x = medCosts['age'])

# %%
sns.boxplot(x = medCosts['age'], y = medCosts['charges'])

# %% [markdown]
# **Bootstrapping the median of the charges variable**
# Finally we are conducting a bootstrapping on the median of the charges variable

# %%
import random

# %%
# original sample median
original_median = medCosts['charges'].median()
original_median
# Out:
# 9382.033

# %%
# boot samples
medians_boot_samples = []
for i in range(1000):
                boot_sample = np.random.choice(medCosts['charges'], 133)  # approximately ten percent of the rows
                medians_boot_samples.append(np.median(boot_sample))
        
np.median(medians_boot_samples)
# Out:
# 9377.9047

# %%
conf_int = np.percentile(medians_boot_samples, [2.5, 97.5])
conf_int
# Out:
# array([ 7731.38256625, 11093.6229    ])
